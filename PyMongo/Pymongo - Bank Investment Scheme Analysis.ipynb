# %%
import pymongo

# %%
import pandas as pd

# %%
bank_df = pd.read_json("C:/Users/Administrator/Downloads/bank_edited.json")

# %%
bank_df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
data = bank_df.to_dict(orient='records')

# %%
def main():
    client = pymongo.MongoClient("localhost:27017")
    database = client['BankDB']
    try:
        database.customers.drop()
    except:
        print("Collection Does not Exist")

    
    collection = database['testcollection1']
    collection.insert_one(product_1)
    collection.insert_many(products)

    allDocuments = collection.find()

    for i in allDocuments:
        print(i)

    #to fetch distinct values from collection of documents
    distinct_product = collection.distinct("name")
    print(distinct_product)

if __name__=="__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 24
#      21     print(distinct_product)
#      23 if __name__=="__main__":
# ---> 24     main()
#
# Cell In[7], line 11, in main()
#       7     print("Collection Does not Exist")
#      10 collection = database['testcollection1']
# ---> 11 collection.insert_one(product_1)
#      12 collection.insert_many(products)
#      14 allDocuments = collection.find()
#
# NameError: name 'product_1' is not defined

# %%
client = pymongo.MongoClient("localhost:27017")

# %%
print(client)

# %%
database = client['BankDB']
collection = database['Bank']

# %%
collection.find_one()

# %% [markdown]
# #### Give marketing success rate (No. of people subscribed / total no. of entries)
