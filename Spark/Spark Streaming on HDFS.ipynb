# %%
from pyspark import SparkConf,SparkContext
from pyspark.streaming import StreamingContext

# %%
config = SparkConf().setAppName("SparkSession")
sc = SparkContext.getOrCreate(conf= config)

# %%
ssc = StreamingContext(sc,5)

# %%
lines = ssc.textFileStream("/SparkStream/")
words = lines.flatMap(lambda line:line.split(" "))
pairs = words.map(lambda word:(word,1))
wordcounts = pairs.reduceByKey(lambda x,y:x+y)
wordcounts = wordcounts.transform(lambda x : x.sortBy(lambda y:y[1], ascending=False))  # to get the top 20 words
# Alternative - dstream.foreachRDD(access RDD and apply RDD methods)
wordcounts.pprint(20)

# %%
ssc.start()
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2024-09-04 17:41:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2024-09-04 17:41:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2024-09-04 17:42:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2024-09-04 17:42:05
# -------------------------------------------
# ('the', 3306)
# ('', 3056)
# ('to', 1827)
# ('and', 1787)
# ('a', 1577)
# ('of', 1235)
# ('was', 1148)
# ('he', 1018)
# ('Harry', 903)
# ('in', 898)
# ('his', 893)
# ('had', 691)
# ('--', 688)
# ('said', 659)
# ('at', 580)
# ('you', 578)
# ('it', 547)
# ('on', 544)
# ('that', 519)
# ('I', 499)
# ...
#
# -------------------------------------------
# Time: 2024-09-04 17:42:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2024-09-04 17:42:15
# ...

# %%
ssc.stop()

# %%
sc.stop()
